# %% [markdown]
# # Module 2 Assignment 2

# %% [markdown]
# **Dataset Overview**:
#
# The growth of supermarkets in most populated cities are increasing and market competitions are also high. The dataset is one of the historical sales of supermarket company which has recorded in 3 different branches for 3 months data.
#
# - `Invoice id` : Computer generated sales slip invoice identification number
# - `Branch`: Branch of supercenter (3 branches are available identified by A, B and C).
# - `City`: Location of supercenters
# - `Customer type`: Type of customers, recorded by Members for customers using member card and Normal for without member card.
# - `Gender`: Gender type of customer
# - `Product line`: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - `Unit price`: Price of each product in $
# - `Quantity`: Number of products purchased by customer
# - `Tax`: 5% tax fee for customer buying
# - `Total`: Total price including tax
# - `Date`: Date of purchase (Record available from January 2019 to March 2019)
# - `Time`: Purchase time (10am to 9pm)
# - `Payment`: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
# - `COGS`: Cost of goods sold
# - `Gross margin percentage`: Gross margin percentage
# - `Gross income`: Gross income
# - `Rating`: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# ### Exercise 1: Loading and Inspecting Data
#
# 1. Load the dataset into a Pandas DataFrame.
# 2. Display the first 10 rows of the DataFrame.
# 3. Show a summary of the DataFrame, including column data types and non-null values.
# 4. Check mean and median of the `Total` column and max and min of the `Unit price` column and print them.
#
# ---

# %%
import pandas as pd

# Load the dataset into a Pandas DataFrame.
# TODO

# %%
# Display the first 10 rows of the DataFrame.
# TODO
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
# Show a summary of the DataFrame, including column data types and non-null values.
# TODO
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# Check mean and median of the 'Total' column and max and min of the 'Unit price' column and print them.
# TODO
# Out:
# Mean Total: 322.966749, Median Total: 253.848
# Max Unit Price: 99.96, Min Unit Price: 10.08

# %% [markdown]
# ### Exercise 2: Data Access and Selection
#
# 1. Access the `City` column and display the first 5 values.
# 2. Get the unique values of the `City` column.
# 3. Access `Product line` and `Unit price` columns.
# 4. Use `.iloc` to select the row at index 15.
# 5. Use `.iloc` to select the first 3 rows and all columns.
# 6. Use `.iloc` to select the first 5 rows and the first 3 columns
# 7. Use `.loc` to select the first 11 rows and the columns from `Product line`, `Unit price`, and `Total`.
#
# ---

# %%
# Access the `City` column and display the first 5 values.
# TODO
# Out:
# 0       Yangon
# 1    Naypyitaw
# 2       Yangon
# 3       Yangon
# 4       Yangon
# Name: City, dtype: object

# %%
# Get the unique values of the `City` column.
# TODO
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
# Extract `Product line` and `Unit price` columns.
# TODO
# Out:
#                Product line  Unit price
# 0         Health and beauty       74.69
# 1    Electronic accessories       15.28
# 2        Home and lifestyle       46.33
# 3         Health and beauty       58.22
# 4         Sports and travel       86.31
# ..                      ...         ...
# 995       Health and beauty       40.35
# 996      Home and lifestyle       97.38
# 997      Food and beverages       31.84
# 998      Home and lifestyle       65.82
# 999     Fashion accessories       88.34
#
# [1000 rows x 2 columns]

# %%
# Row at index 15 using `iloc`
# TODO
# Out:
# Invoice ID                       299-46-1805
# Branch                                     B
# City                                Mandalay
# Customer type                         Member
# Gender                                Female
# Product line               Sports and travel
# Unit price                             93.72
# Quantity                                   6
# Tax 5%                                28.116
# Total                                590.436
# Date                               1/15/2019
# Time                                   16:19
# Payment                                 Cash
# cogs                                  562.32
# gross margin percentage             4.761905
# gross income                          28.116
# Rating                                   4.5
# Name: 15, dtype: object

# %%
# Use `.iloc` to select the first 3 rows and all columns.
# TODO
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4

# %%
# Select the first 5 rows and the first 3 columns
# TODO
# Out:
#   Branch       City Customer type
# 0      A     Yangon        Member
# 1      C  Naypyitaw        Normal
# 2      A     Yangon        Normal
# 3      A     Yangon        Member
# 4      A     Yangon        Normal

# %%
# Select the first 11 rows and the columns from 'Product line', 'Unit price', and 'Total'.
# TODO
# Out:
#               Product line  Unit price     Total
# 0        Health and beauty       74.69  548.9715
# 1   Electronic accessories       15.28   80.2200
# 2       Home and lifestyle       46.33  340.5255
# 3        Health and beauty       58.22  489.0480
# 4        Sports and travel       86.31  634.3785
# 5   Electronic accessories       85.39  627.6165
# 6   Electronic accessories       68.84  433.6920
# 7       Home and lifestyle       73.56  772.3800
# 8        Health and beauty       36.26   76.1460
# 9       Food and beverages       54.84  172.7460
# 10     Fashion accessories       14.48   60.8160

# %% [markdown]
# ### Exercise 3: Adding New Columns
#
# 1. Add a new column `Cost per item` by dividing the `Total` by `Quantity`.
# 2. Add a new column `Revenue` by multiplying `Quantity` and `Unit price`.
# 3. Add a new column `High spender` where the value is `True` if the `Total` is greater than 200, otherwise `False`.
#
# ---

# %%
# Add a new column `Cost per item` by dividing the `Total` by `Quantity`.
# TODO

# %%
# Add a new column `Revenue` to the DataFrame by multiplying `Quantity` and `Unit price`.
# TODO

# %%
# Add a new column `High spender` where the value is `True` if the `Total` is greater than 200, otherwise `False`.
# TODO

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ### Exercise 4 (Challenge):
#
# - Add a new column named `Rating category` with values 'Poor', 'Average', 'Good', and 'Excellent' based on `Rating`.
#
# For this question, you will need to do a self-study on the `cut()` method from the Pandas library.
# Discuss it in your group and try to help each other understand its functionality well.
#
# Use these bins and labels for the categories.
# 1. bins = [0, 4, 6, 8, 10]
# 2. As catogery labels, use these: 'Poor', 'Average', 'Good', and 'Excellent'
#
# ---

# %%
# Define the bins and labels
# TODO

# Using the cut() method to create a new column 'Rating category'
# TODO

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ### Exercise 5: Renaming and Dropping Columns
#
# 1. Rename the `cogs` to `COGS`, `gross income` to `Gross income`, `gross margin percentage` to `Gross margin percentage`, and `Tax 5%` to `Tax`.
# 2. Drop the `COGS` column from the DataFrame and display the first 5 rows of the updated DataFrame.
#
# ---

# %%
# Rename the `cogs` to `COGS`, `gross income` to `Gross income`, `gross margin percentage` to `Gross margin percentage`, and `Tax 5%` to `Tax`.
# TODO

# %%
# Drop the `COGS` column from the DataFrame and display the first 5 rows of the updated DataFrame.
# TODO

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Tax     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment  Gross margin percentage  Gross income  Rating  \
# 0  13:08      Ewallet                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ### Exercise 6: Conditional Selection and Comparision Operators
#
# 1. Show all the transactions where `Gender` is "Female".
# 2. Show the details of the transaction with Invoice ID "750-67-8428".
# 3. Using loc method, show the transactions where `Payment` is made by Credit card.
# 4. Using loc method, show the `Total` column of the transactions where `Branch` is "A".
# 5. Using loc method, show only the columns `Customer type` and `Total` of the transactions where `Product line` is "Health and beauty".
#
# ---

# %%
# Show all the transactions where `Gender` is "Female".
# TODO
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# Show the details of the transaction with Invoice ID `692-92-5582`.
# TODO
# Out:
#     Invoice ID Branch      City Customer type  Gender        Product line  \
# 9  692-92-5582      B  Mandalay        Member  Female  Food and beverages
#
#    Unit price  Quantity    Tax    Total       Date   Time      Payment  \
# 9       54.84         3  8.226  172.746  2/20/2019  13:27  Credit card
#
#    Gross margin percentage  Gross income  Rating  Cost per item  Revenue  \
# 9                 4.761905         8.226     5.9         57.582   164.52
#
#    High spender Rating category
# 9         False         Average

# %%
# Using loc method, show the transactions where `Payment` is made by Credit card.
# TODO
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 2    631-41-3108      A    Yangon        Normal    Male
# 8    665-32-9167      A    Yangon        Member  Female
# 9    692-92-5582      B  Mandalay        Member  Female
# 16   656-95-9349      A    Yangon        Member  Female
# 17   765-26-6951      A    Yangon        Normal    Male
# ..           ...    ...       ...           ...     ...
# 978  156-20-0370      B  Mandalay        Normal  Female
# 979  151-33-7434      B  Mandalay        Normal  Female
# 987  552-44-5977      B  Mandalay        Member    Male
# 989  430-53-4718      B  Mandalay        Member    Male
# 990  886-18-2897      A    Yangon        Normal  Female
#
#                Product line  Unit price  Quantity      Tax     Total  \
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 8         Health and beauty       36.26         2   3.6260   76.1460
# 9        Food and beverages       54.84         3   8.2260  172.7460
# ...

# %%
# Using loc method, show the `Total` column of the transactions where `Branch` is "A".
# TODO
# Out:
# 0      548.9715
# 2      340.5255
# 3      489.0480
# 4      634.3785
# 6      433.6920
#          ...
# 990    296.9400
# 992    121.8630
# 997     33.4320
# 998     69.1110
# 999    649.2990
# Name: Total, Length: 340, dtype: float64

# %%
# Using loc method, show only the columns `Customer type` and `Total` of the transactions where `Product line` is "Health and beauty".
# TODO
# Out:
#     Customer type     Total
# 0          Member  548.9715
# 3          Member  489.0480
# 8          Member   76.1460
# 14         Normal  749.4900
# 16         Member  506.6355
# ..            ...       ...
# 983        Normal  734.7060
# 986        Normal   30.9960
# 987        Member  520.8000
# 989        Member  633.1080
# 995        Normal   42.3675
#
# [152 rows x 2 columns]

# %% [markdown]
# ### Exercise 7: Advanced Filtering and Logical Operators
#
# 1. Filter rows where `Payment` is "Credit card" and `Rating` is greater than 7 and create a dataframe called filtered_1.
# 2. Filter rows where `Product line` is "Electronic accessories" or `Branch` is "A" and create a dataframe called filtered_2.
# 3. Filter rows where `Total` is greater than 200 and `Payment` is "Credit card" and create a dataframe called high_total_credit.
# 4. Filter rows where `High spender` is "True" and `Payment` is "Ewallet" and create a dataframe called high_spenders_ewallet.
# 5. Using loc method, show the transactions where `City` is "Yangon" and `Branch` is "A".
# 6. Using loc method, show the transactions where `Customer type` is "Member" and `Gender` is "Male".
# 7. Using loc method, show the transactions where `Quantity` is greater than 8 and `Gross income` is less than 50 and `Payment` is not "Cash".
# 8. Using loc methods, show the transaction where `Unit price` is between 20 and 25 (inclusive) and `Quantity` is 7. Learn more about the `between` method.
# 9. Using loc method, show the transactions where `Product line` is "Fashion accessories" and `Quantity` is greater than 5. Show only the columns `Total` and `Payment`.
# 10. Using loc method, show the transactions where `Rating` is greater or equal to 9 and `Gender` is "Female". Show only the columns `Branch` and `Rating`.
#
# ---

# %%
# Filter rows where `Payment` is "Credit card" and `Rating` is greater than 7 and create a dataframe called filtered_1.
# TODO
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 2    631-41-3108      A    Yangon        Normal    Male
# 8    665-32-9167      A    Yangon        Member  Female
# 18   329-62-1586      A    Yangon        Normal    Male
# 25   227-03-5010      A    Yangon        Member  Female
# 27   189-17-4241      A    Yangon        Normal  Female
# ..           ...    ...       ...           ...     ...
# 962  593-08-5916      A    Yangon        Normal  Female
# 967  195-06-0432      A    Yangon        Member    Male
# 969  214-30-2776      B  Mandalay        Member  Female
# 970  746-04-1077      B  Mandalay        Member  Female
# 989  430-53-4718      B  Mandalay        Member    Male
#
#                Product line  Unit price  Quantity      Tax     Total  \
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 8         Health and beauty       36.26         2   3.6260   76.1460
# 18       Food and beverages       54.67         3   8.2005  172.2105
# ...

# %%
# Filter rows where `Product line` is "Electronic accessories" or `Branch` is "A" and create a dataframe called filtered_2. 
# TODO
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 992  745-74-0715      A     Yangon        Normal    Male
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity      Tax     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
# Filter rows where `Total` is greater than 200 and `Payment` is "Credit card" and create a dataframe called high_total_credit. 
# TODO
# Out:
#       Invoice ID Branch      City Customer type  Gender         Product line  \
# 2    631-41-3108      A    Yangon        Normal    Male   Home and lifestyle
# 16   656-95-9349      A    Yangon        Member  Female    Health and beauty
# 17   765-26-6951      A    Yangon        Normal    Male    Sports and travel
# 25   227-03-5010      A    Yangon        Member  Female   Home and lifestyle
# 30   871-79-8483      B  Mandalay        Normal    Male  Fashion accessories
# ..           ...    ...       ...           ...     ...                  ...
# 967  195-06-0432      A    Yangon        Member    Male   Home and lifestyle
# 970  746-04-1077      B  Mandalay        Member  Female   Food and beverages
# 987  552-44-5977      B  Mandalay        Member    Male    Health and beauty
# 989  430-53-4718      B  Mandalay        Member    Male    Health and beauty
# 990  886-18-2897      A    Yangon        Normal  Female   Food and beverages
#
# ...

# %%
# Filter rows where `High spender` is "True" and `Payment` is "Ewallet" and create a dataframe called high_spenders_ewallet. 
# TODO
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 6    355-53-5943      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 982  139-32-4183      A     Yangon        Member  Female
# 985  374-38-5555      B   Mandalay        Normal  Female
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 991  602-16-6955      B   Mandalay        Normal  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity      Tax      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 3         Health and beauty       58.22         8  23.2880   489.0480
# ...

# %%
# Using loc method, show the transactions where `City` is "Yangon" and `Branch` is "A".
# TODO
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2    631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3    123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4    373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6    355-53-5943      A  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897      A  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715      A  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313      A  Yangon        Member    Male      Food and beverages
# 998  347-56-2442      A  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807      A  Yangon        Member  Female     Fashion accessories
#
# ...

# %%
# Using loc method, show the transactions where `Customer type` is "Member" and `Gender` is "Male".
# TODO
# Out:
#       Invoice ID Branch       City Customer type Gender  \
# 3    123-19-1176      A     Yangon        Member   Male
# 11   529-56-3974      B   Mandalay        Member   Male
# 20   300-71-4605      C  Naypyitaw        Member   Male
# 24   549-59-1358      A     Yangon        Member   Male
# 31   149-71-6266      B   Mandalay        Member   Male
# ..           ...    ...        ...           ...    ...
# 980  728-47-9078      C  Naypyitaw        Member   Male
# 987  552-44-5977      B   Mandalay        Member   Male
# 988  267-62-7380      C  Naypyitaw        Member   Male
# 989  430-53-4718      B   Mandalay        Member   Male
# 997  727-02-1313      A     Yangon        Member   Male
#
#                Product line  Unit price  Quantity      Tax     Total  \
# 3         Health and beauty       58.22         8  23.2880  489.0480
# 11   Electronic accessories       25.51         4   5.1020  107.1420
# 20   Electronic accessories       86.04         5  21.5100  451.7100
# ...

# %%
# Using loc method, show the transactions where `Quantity` is greater than 8 and `Gross income` is less than 50 and `Payment` is not "Cash".
# TODO
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 13   252-56-2699      A     Yangon        Normal    Male
# 37   272-65-1806      A     Yangon        Normal  Female
# 46   370-41-7321      B   Mandalay        Member    Male
# 47   727-46-3608      B   Mandalay        Member  Female
# ..           ...    ...        ...           ...     ...
# 982  139-32-4183      A     Yangon        Member  Female
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 991  602-16-6955      B   Mandalay        Normal  Female
# 993  690-01-6631      B   Mandalay        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity      Tax      Total  \
# 7        Home and lifestyle       73.56        10  36.7800   772.3800
# 13       Food and beverages       43.19        10  21.5950   453.4950
# ...

# %%
# Using loc methods, show the transaction where `Unit price` is between 20 and 25 (inclusive) and `Quantity` is 7. Learn more about the `between` method.
# TODO
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 92   873-51-0671      A     Yangon        Member  Female    Sports and travel
# 177  139-52-2867      C  Naypyitaw        Normal  Female  Fashion accessories
# 591  788-07-8452      C  Naypyitaw        Member  Female   Home and lifestyle
# 870  873-14-6353      A     Yangon        Member    Male   Food and beverages
#
#      Unit price  Quantity     Tax     Total       Date   Time      Payment  \
# 92        21.98         7  7.6930  161.5530  1/10/2019  16:42      Ewallet
# 177       22.51         7  7.8785  165.4485  2/13/2019  10:50  Credit card
# 591       24.24         7  8.4840  178.1640  1/27/2019  17:38      Ewallet
# 870       24.82         7  8.6870  182.4270  2/16/2019  10:33  Credit card
#
#      Gross margin percentage  Gross income  Rating  Cost per item  Revenue  \
# 92                  4.761905        7.6930     5.1        23.0790   153.86
# ...

# %%
# Using loc method, show the transactions where `Product line` is "Fashion accessories" and `Quantity` is greater than 5. Show only the columns `Total` and `Payment`.
# TODO
# Out:
#         Total      Payment
# 13   453.4950      Ewallet
# 43   829.0800         Cash
# 47   189.0945      Ewallet
# 50   671.7900         Cash
# 70   939.5400  Credit card
# ..        ...          ...
# 949  222.0120      Ewallet
# 956  477.1305         Cash
# 959  932.3370         Cash
# 970  888.6150  Credit card
# 977  167.5800      Ewallet
#
# [81 rows x 2 columns]

# %%
# Using loc method, show the transactions where `Rating` is greater or equal to 9 and `Gender` is "Female". Show only the columns `Branch` and `Rating`.
# TODO
# Out:
#     Branch  Rating
# 0        A     9.1
# 1        C     9.6
# 28       B     9.6
# 45       B     9.5
# 60       C    10.0
# ..     ...     ...
# 931      C     9.5
# 934      B     9.8
# 968      A     9.5
# 969      B     9.0
# 970      B     9.0
#
# [83 rows x 2 columns]

# %% [markdown]
# #### Exercise 8: Challenge
# 1. Learn how `nlargest()`, `nsmallest()`, and `isin()` methods work in pandas.
# 2. Using these methods filter and show transactions where `Payment` is "Credit card" and `Total` is in the top 10.
# 3. Show transactions on "January 28 2019", where `Branch` is "A" or "B"
#
# ---

# %%
# Transactions where `Payment` is "Credit card" and `Total` is in the top 10
# TODO

# Show transactions on "January 28, 2019" where `Branch` is "A" or "B"
# TODO
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 31   149-71-6266      B  Mandalay        Member    Male
# 445  390-80-5128      B  Mandalay        Member  Female
# 505  726-29-6793      A    Yangon        Member    Male
# 826  222-42-0244      B  Mandalay        Member  Female
# 872  544-55-9589      B  Mandalay        Member  Female
# 895  699-88-1972      B  Mandalay        Normal    Male
# 903  865-41-9075      A    Yangon        Normal    Male
# 989  430-53-4718      B  Mandalay        Member    Male
#
#                Product line  Unit price  Quantity      Tax     Total  \
# 31        Sports and travel       78.07         9  35.1315  737.7615
# 445       Health and beauty       19.15         1   0.9575   20.1075
# 505  Electronic accessories       24.18         8   9.6720  203.1120
# 826       Health and beauty       72.11         9  32.4495  681.4395
# 872  Electronic accessories       21.43        10  10.7150  225.0150
# ...
